# %% [markdown]
# # Practice using F1 data from Ergast API (compiled by Kaggle)
# [F1 World Championship 1950-2023](https://www.kaggle.com/datasets/rohanrao/formula-1-world-championship-1950-2020)

# %%
# Use this with the F1 dataset
# Install DuckDB and jupysql
# %pip install -U jupysql duckdb-engine
# Out:
# Requirement already satisfied: jupysql in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (0.10.9)
# Requirement already satisfied: duckdb-engine in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (0.10.0)
# Requirement already satisfied: prettytable in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from jupysql) (3.9.0)
# Requirement already satisfied: sqlalchemy in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from jupysql) (2.0.25)
# Requirement already satisfied: sqlparse in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from jupysql) (0.4.4)
# Requirement already satisfied: ipython-genutils>=0.1.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from jupysql) (0.2.0)
# Requirement already satisfied: jinja2 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from jupysql) (3.1.3)
# Requirement already satisfied: sqlglot>=11.3.7 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from jupysql) (20.11.0)
# Requirement already satisfied: ploomber-core>=0.2.7 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from jupysql) (0.2.25)
# Requirement already satisfied: jupysql-plugin in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from jupysql) (0.4.1)
# Requirement already satisfied: duckdb>=0.4.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from duckdb-engine) (0.9.2)
# Requirement already satisfied: pyyaml in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from ploomber-core>=0.2.7->jupysql) (6.0.1)
# Requirement already satisfied: posthog in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from ploomber-core>=0.2.7->jupysql) (3.3.4)
# Requirement already satisfied: typing-extensions>=4.6.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from sqlalchemy->jupysql) (4.9.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from jinja2->jupysql) (2.1.4)
# Requirement already satisfied: wcwidth in /Users/Daphne/Library/Python/3.11/lib/python/site-packages (from prettytable->jupysql) (0.2.13)
# Requirement already satisfied: requests<3.0,>=2.7 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from posthog->ploomber-core>=0.2.7->jupysql) (2.31.0)
# Requirement already satisfied: six>=1.5 in /Users/Daphne/Library/Python/3.11/lib/python/site-packages (from posthog->ploomber-core>=0.2.7->jupysql) (1.16.0)
# Requirement already satisfied: monotonic>=1.5 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from posthog->ploomber-core>=0.2.7->jupysql) (1.6)
# Requirement already satisfied: backoff>=1.10.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from posthog->ploomber-core>=0.2.7->jupysql) (2.2.1)
# Requirement already satisfied: python-dateutil>2.1 in /Users/Daphne/Library/Python/3.11/lib/python/site-packages (from posthog->ploomber-core>=0.2.7->jupysql) (2.8.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from requests<3.0,>=2.7->posthog->ploomber-core>=0.2.7->jupysql) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from requests<3.0,>=2.7->posthog->ploomber-core>=0.2.7->jupysql) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from requests<3.0,>=2.7->posthog->ploomber-core>=0.2.7->jupysql) (2.1.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from requests<3.0,>=2.7->posthog->ploomber-core>=0.2.7->jupysql) (2023.11.17)
# Note: you may need to restart the kernel to use updated packages.

# %%
# Load packages
import pandas as pd
import zipfile
import os
import duckdb as ddb

# Configure the SQL magic
# %load_ext sql
# %config SqlMagic.autopandas = True
# %config SqlMagic.feedback = False
# %config SqlMagic.displaycon = False

# Use %sql magic to connect to the DuckDB database
# %sql duckdb:///:memory:

# Unzip the data
with zipfile.ZipFile('F1.zip', 'r') as zip_ref:
    zip_ref.extractall('data')

# Load each CSV into a DataFrame
tables = []
for f in os.listdir('data'):
    if f.endswith('.csv'):
        table_name = f.replace('.csv', '')
        file_path = os.path.join('data', f)
        # tables[table_name] = pd.read_csv(file_path)
        tables.append(table_name)
        globals()[table_name] = pd.read_csv(file_path)

# %sql SELECT * FROM results LIMIT 5
# Out:
# /var/folders/z9/93thyyl57vd2c58_d39dsb7m0000gn/T/ipykernel_47717/679021113.py:2: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd
#    resultId  raceId  driverId  constructorId number  grid position  \
# 0         1      18         1              1     22     1        1
# 1         2      18         2              2      3     5        2
# 2         3      18         3              3      7     7        3
# 3         4      18         4              4      5    11        4
# 4         5      18         5              1     23     3        5
#
#   positionText  positionOrder  points  laps         time milliseconds  \
# 0            1              1    10.0    58  1:34:50.616      5690616
# 1            2              2     8.0    58       +5.478      5696094
# 2            3              3     6.0    58       +8.163      5698779
# 3            4              4     5.0    58      +17.181      5707797
# 4            5              5     4.0    58      +18.014      5708630
#
#   fastestLap rank fastestLapTime fastestLapSpeed  statusId
# 0         39    2       1:27.452         218.300         1
# 1         41    3       1:27.739         217.586         1
# 2         41    5       1:28.090         216.719         1
# 3         58    7       1:28.603         215.464         1
# 4         43    1       1:27.418         218.385         1

# %% [markdown]
# ## Exploring the data

# %%
globals()['results']
# Out:
#        resultId  raceId  driverId  constructorId number  grid position  \
# 0             1      18         1              1     22     1        1
# 1             2      18         2              2      3     5        2
# 2             3      18         3              3      7     7        3
# 3             4      18         4              4      5    11        4
# 4             5      18         5              1     23     3        5
# ...         ...     ...       ...            ...    ...   ...      ...
# 26075     26081    1110       817            213      3    19       16
# 26076     26082    1110       858              3      2    18       17
# 26077     26083    1110       807            210     27     0       18
# 26078     26084    1110       832              6     55     4       \N
# 26079     26085    1110       857              1     81     5       \N
#
#       positionText  positionOrder  points  laps         time milliseconds  \
# 0                1              1    10.0    58  1:34:50.616      5690616
# 1                2              2     8.0    58       +5.478      5696094
# 2                3              3     6.0    58       +8.163      5698779
# 3                4              4     5.0    58      +17.181      5707797
# 4                5              5     4.0    58      +18.014      5708630
# ...            ...            ...     ...   ...          ...          ...
# 26075           16             16     0.0    44    +1:43.071      5053521
# 26076           17             17     0.0    44    +1:44.476      5054926
# 26077           18             18     0.0    44    +1:50.450      5060900
# 26078            R             19     0.0    23           \N           \N
# 26079            R             20     0.0     0           \N           \N
#
#       fastestLap rank fastestLapTime fastestLapSpeed  statusId
# 0             39    2       1:27.452         218.300         1
# 1             41    3       1:27.739         217.586         1
# 2             41    5       1:28.090         216.719         1
# 3             58    7       1:28.603         215.464         1
# 4             43    1       1:27.418         218.385         1
# ...          ...  ...            ...             ...       ...
# 26075         25   15       1:50.994         227.169         1
# 26076         37    9       1:50.486         228.213         1
# 26077         26    4       1:49.907         229.415         1
# 26078          9   19       1:53.138         222.864       130
# 26079         \N    0             \N              \N       130
#
# [26080 rows x 18 columns]

# %%
# Query using %sql magic
res = %sql SELECT * FROM results LIMIT 5
display(res)
# Out:
#    resultId  raceId  driverId  constructorId number  grid position  \
# 0         1      18         1              1     22     1        1
# 1         2      18         2              2      3     5        2
# 2         3      18         3              3      7     7        3
# 3         4      18         4              4      5    11        4
# 4         5      18         5              1     23     3        5
#
#   positionText  positionOrder  points  laps         time milliseconds  \
# 0            1              1    10.0    58  1:34:50.616      5690616
# 1            2              2     8.0    58       +5.478      5696094
# 2            3              3     6.0    58       +8.163      5698779
# 3            4              4     5.0    58      +17.181      5707797
# 4            5              5     4.0    58      +18.014      5708630
#
#   fastestLap rank fastestLapTime fastestLapSpeed  statusId
# 0         39    2       1:27.452         218.300         1
# 1         41    3       1:27.739         217.586         1
# 2         41    5       1:28.090         216.719         1
# 3         58    7       1:28.603         215.464         1
# 4         43    1       1:27.418         218.385         1

# %%
# Query using DuckDB
ddb.sql("SELECT * FROM results LIMIT 5")
# Out:
# ┌──────────┬────────┬──────────┬───────────────┬─────────┬───┬─────────┬────────────────┬─────────────────┬──────────┐
# │ resultId │ raceId │ driverId │ constructorId │ number  │ … │  rank   │ fastestLapTime │ fastestLapSpeed │ statusId │
# │  int64   │ int64  │  int64   │     int64     │ varchar │   │ varchar │    varchar     │     varchar     │  int64   │
# ├──────────┼────────┼──────────┼───────────────┼─────────┼───┼─────────┼────────────────┼─────────────────┼──────────┤
# │        1 │     18 │        1 │             1 │ 22      │ … │ 2       │ 1:27.452       │ 218.300         │        1 │
# │        2 │     18 │        2 │             2 │ 3       │ … │ 3       │ 1:27.739       │ 217.586         │        1 │
# │        3 │     18 │        3 │             3 │ 7       │ … │ 5       │ 1:28.090       │ 216.719         │        1 │
# │        4 │     18 │        4 │             4 │ 5       │ … │ 7       │ 1:28.603       │ 215.464         │        1 │
# │        5 │     18 │        5 │             1 │ 23      │ … │ 1       │ 1:27.418       │ 218.385         │        1 │
# ├──────────┴────────┴──────────┴───────────────┴─────────┴───┴─────────┴────────────────┴─────────────────┴──────────┤
# │ 5 rows                                                                                        18 columns (9 shown) │
# └────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┘

# %%
query = """SELECT cs.position, c.name 
FROM constructor_standings cs 
LEFT JOIN constructors c on cs.constructorId=c.constructorId 
ORDER BY position LIMIT 5"""
ddb.sql(query)
# Out:
# ┌──────────┬────────────┐
# │ position │    name    │
# │  int64   │  varchar   │
# ├──────────┼────────────┤
# │        1 │ McLaren    │
# │        1 │ McLaren    │
# │        1 │ BMW Sauber │
# │        1 │ Ferrari    │
# │        1 │ Ferrari    │
# └──────────┴────────────┘

# %% [markdown]
# ## Longest pit times along with driver names and

# %% [markdown]
# #### Get the `raceId`, `driverId`, `constructorId` for which longest pit stops happened
# (by joining `pit_stops` and `results`)

# %%
longest_pit = ddb.sql("""SELECT pit_stops.raceId, pit_stops.driverId, pit_stops.duration, pit_stops.stop, pit_stops.lap, results.constructorId
                      FROM pit_stops
                      LEFT JOIN results ON pit_stops.raceId = results.raceId AND pit_stops.driverId = results.driverId
                      ORDER BY pit_stops.duration DESC""")

longest_pit
# Out:
# ┌────────┬──────────┬──────────┬───────┬───────┬───────────────┐
# │ raceId │ driverId │ duration │ stop  │  lap  │ constructorId │
# │ int64  │  int64   │ varchar  │ int64 │ int64 │     int64     │
# ├────────┼──────────┼──────────┼───────┼───────┼───────────────┤
# │   1092 │      855 │ 6:50.005 │     1 │     2 │            51 │
# │   1092 │       20 │ 6:49.647 │     1 │     2 │           117 │
# │   1092 │      842 │ 6:49.011 │     2 │     2 │           213 │
# │   1092 │      849 │ 6:47.673 │     1 │     2 │             3 │
# │   1092 │      822 │ 6:47.553 │     1 │     2 │            51 │
# │   1092 │      846 │ 6:46.256 │     1 │     2 │             1 │
# │   1092 │      852 │ 6:42.478 │     1 │     2 │           213 │
# │   1092 │      825 │ 6:42.029 │     1 │     2 │           210 │
# │   1092 │      817 │ 6:41.749 │     1 │     2 │             1 │
# │   1092 │      847 │ 6:41.057 │     1 │     2 │           131 │
# │     ·  │        · │   ·      │     · │     · │            ·  │
# │     ·  │        · │   ·      │     · │     · │            ·  │
# │     ·  │        · │   ·      │     · │     · │            ·  │
# │    861 │       37 │ 15.684   │     1 │    13 │           164 │
# │    976 │      807 │ 15.638   │     2 │    17 │             4 │
# │   1057 │        4 │ 15.432   │     3 │    47 │           214 │
# │   1057 │        1 │ 15.432   │     2 │    47 │           131 │
# │    976 │      840 │ 15.327   │     2 │    17 │             3 │
# │    976 │      815 │ 15.278   │     2 │    17 │            10 │
# │   1057 │      815 │ 15.277   │     2 │    47 │             9 │
# │    976 │        1 │ 15.234   │     2 │    17 │           131 │
# │    976 │       20 │ 15.174   │     2 │    17 │             6 │
# │    976 │      817 │ 15.135   │     3 │    17 │             9 │
# ├────────┴──────────┴──────────┴───────┴───────┴───────────────┤
# │ ? rows (>9999 rows, 20 shown)                      6 columns │
# └──────────────────────────────────────────────────────────────┘

# %% [markdown]
# #### Get the race name, race year, constructor names, driver names in which longest pit stops happened
# (by finding the related information in `drivers`, `races`, and `constructors` using left join with `longest_pit`)

# %%
ddb.sql("""SELECT longest_pit.duration, longest_pit.stop, longest_pit.lap, races.name, races.year, drivers.forename, drivers.surname,  constructors.name
        FROM longest_pit
        LEFT JOIN drivers ON longest_pit.driverId=drivers.driverId
        LEFT JOIN races ON longest_pit.raceId=races.raceId
        LEFT JOIN constructors ON longest_pit.constructorId=constructors.constructorId
        WHERE races.year<=2021
        """)
# Out:
# ┌──────────┬───────┬───────┬───────────────────────────┬───────┬────────────┬────────────┬────────────────┐
# │ duration │ stop  │  lap  │           name            │ year  │  forename  │  surname   │      name      │
# │ varchar  │ int64 │ int64 │          varchar          │ int64 │  varchar   │  varchar   │    varchar     │
# ├──────────┼───────┼───────┼───────────────────────────┼───────┼────────────┼────────────┼────────────────┤
# │ 59.555   │     5 │    52 │ Hungarian Grand Prix      │  2015 │ Kimi       │ Räikkönen  │ Ferrari        │
# │ 59.291   │     1 │     1 │ Belgian Grand Prix        │  2019 │ Carlos     │ Sainz      │ McLaren        │
# │ 57.601   │     3 │    33 │ Emilia Romagna Grand Prix │  2021 │ Fernando   │ Alonso     │ Alpine F1 Team │
# │ 56.710   │     1 │     1 │ Azerbaijan Grand Prix     │  2018 │ Fernando   │ Alonso     │ McLaren        │
# │ 56.611   │     2 │    16 │ Turkish Grand Prix        │  2011 │ Vitantonio │ Liuzzi     │ HRT            │
# │ 55.789   │     1 │    24 │ Australian Grand Prix     │  2015 │ Carlos     │ Sainz      │ Toro Rosso     │
# │ 55.697   │     2 │    16 │ British Grand Prix        │  2016 │ Jolyon     │ Palmer     │ Renault        │
# │ 54.673   │     1 │     8 │ Spanish Grand Prix        │  2021 │ Antonio    │ Giovinazzi │ Alfa Romeo     │
# │ 52.874   │     2 │    62 │ Sakhir Grand Prix         │  2020 │ Valtteri   │ Bottas     │ Mercedes       │
# │ 52.836   │     1 │     1 │ Malaysian Grand Prix      │  2014 │ Jules      │ Bianchi    │ Marussia       │
# │   ·      │     · │     · │          ·                │    ·  │   ·        │    ·       │    ·           │
# │   ·      │     · │     · │          ·                │    ·  │   ·        │    ·       │    ·           │
# │   ·      │     · │     · │          ·                │    ·  │   ·        │    ·       │    ·           │
# │ 29.793   │     2 │     7 │ Japanese Grand Prix       │  2012 │ Romain     │ Grosjean   │ Lotus F1       │
# │ 29.702   │     1 │    15 │ Singapore Grand Prix      │  2013 │ Romain     │ Grosjean   │ Lotus F1       │
# │ 22.016   │     1 │    23 │ Austrian Grand Prix       │  2015 │ Romain     │ Grosjean   │ Lotus F1       │
# │ 21.143   │     3 │    22 │ Japanese Grand Prix       │  2012 │ Romain     │ Grosjean   │ Lotus F1       │
# │ 20.976   │     1 │    36 │ Indian Grand Prix         │  2012 │ Romain     │ Grosjean   │ Lotus F1       │
# │ 20.479   │     1 │    16 │ European Grand Prix       │  2012 │ Romain     │ Grosjean   │ Lotus F1       │
# │ 1:13.009 │     3 │    33 │ Singapore Grand Prix      │  2013 │ Romain     │ Grosjean   │ Lotus F1       │
# │ 21.884   │     1 │     3 │ Austrian Grand Prix       │  2014 │ Romain     │ Grosjean   │ Lotus F1       │
# │ 21.681   │     1 │    13 │ Korean Grand Prix         │  2012 │ Romain     │ Grosjean   │ Lotus F1       │
# │ 20.935   │     2 │    31 │ Korean Grand Prix         │  2012 │ Romain     │ Grosjean   │ Lotus F1       │
# ├──────────┴───────┴───────┴───────────────────────────┴───────┴────────────┴────────────┴────────────────┤
# │ 8829 rows (20 shown)                                                                          8 columns │
# └─────────────────────────────────────────────────────────────────────────────────────────────────────────┘

# %%
ddb.sql("""SELECT longest_pit.duration, longest_pit.stop, longest_pit.lap, races.name, races.year, drivers.forename, drivers.surname,  constructors.name
        FROM longest_pit
        LEFT JOIN drivers ON longest_pit.driverId=drivers.driverId
        LEFT JOIN races ON longest_pit.raceId=races.raceId
        LEFT JOIN constructors ON longest_pit.constructorId=constructors.constructorId
        WHERE races.year = 2021
        ORDER BY longest_pit.duration DESC
        """)
# Out:
# ┌──────────┬───────┬───────┬───────────────────────────┬───────┬───────────┬────────────┬────────────────┐
# │ duration │ stop  │  lap  │           name            │ year  │ forename  │  surname   │      name      │
# │ varchar  │ int64 │ int64 │          varchar          │ int64 │  varchar  │  varchar   │    varchar     │
# ├──────────┼───────┼───────┼───────────────────────────┼───────┼───────────┼────────────┼────────────────┤
# │ 57.601   │     3 │    33 │ Emilia Romagna Grand Prix │  2021 │ Fernando  │ Alonso     │ Alpine F1 Team │
# │ 56.733   │     5 │    33 │ Emilia Romagna Grand Prix │  2021 │ Esteban   │ Ocon       │ Alpine F1 Team │
# │ 56.083   │     4 │    33 │ Emilia Romagna Grand Prix │  2021 │ Pierre    │ Gasly      │ AlphaTauri     │
# │ 54.673   │     1 │     8 │ Spanish Grand Prix        │  2021 │ Antonio   │ Giovinazzi │ Alfa Romeo     │
# │ 52.043   │     5 │    33 │ Emilia Romagna Grand Prix │  2021 │ Sebastian │ Vettel     │ Aston Martin   │
# │ 51.222   │     4 │    32 │ Emilia Romagna Grand Prix │  2021 │ Mick      │ Schumacher │ Haas F1 Team   │
# │ 51.007   │     1 │     5 │ Emilia Romagna Grand Prix │  2021 │ Mick      │ Schumacher │ Haas F1 Team   │
# │ 49.729   │     4 │    32 │ Emilia Romagna Grand Prix │  2021 │ Nikita    │ Mazepin    │ Haas F1 Team   │
# │ 46.315   │     2 │    26 │ Styrian Grand Prix        │  2021 │ George    │ Russell    │ Williams       │
# │ 44.608   │     1 │    28 │ Emilia Romagna Grand Prix │  2021 │ Sergio    │ Pérez      │ Red Bull       │
# │   ·      │     · │     · │           ·               │    ·  │   ·       │   ·        │    ·           │
# │   ·      │     · │     · │           ·               │    ·  │   ·       │   ·        │    ·           │
# │   ·      │     · │     · │           ·               │    ·  │   ·       │   ·        │    ·           │
# │ 15.119   │     2 │    47 │ Azerbaijan Grand Prix     │  2021 │ Carlos    │ Sainz      │ Ferrari        │
# │ 15.092   │     2 │    47 │ Azerbaijan Grand Prix     │  2021 │ Charles   │ Leclerc    │ Ferrari        │
# │ 15.085   │     2 │    47 │ Azerbaijan Grand Prix     │  2021 │ Pierre    │ Gasly      │ AlphaTauri     │
# │ 15.064   │     2 │    47 │ Azerbaijan Grand Prix     │  2021 │ Kimi      │ Räikkönen  │ Alfa Romeo     │
# │ 15.058   │     4 │    47 │ Azerbaijan Grand Prix     │  2021 │ Mick      │ Schumacher │ Haas F1 Team   │
# │ 15.054   │     4 │    46 │ Azerbaijan Grand Prix     │  2021 │ Nikita    │ Mazepin    │ Haas F1 Team   │
# │ 14.994   │     2 │    47 │ Azerbaijan Grand Prix     │  2021 │ Daniel    │ Ricciardo  │ McLaren        │
# │ 14.945   │     2 │    47 │ Azerbaijan Grand Prix     │  2021 │ Sebastian │ Vettel     │ Aston Martin   │
# │ 14.943   │     2 │    47 │ Azerbaijan Grand Prix     │  2021 │ Yuki      │ Tsunoda    │ AlphaTauri     │
# │ 14.881   │     3 │    47 │ Azerbaijan Grand Prix     │  2021 │ Antonio   │ Giovinazzi │ Alfa Romeo     │
# ├──────────┴───────┴───────┴───────────────────────────┴───────┴───────────┴────────────┴────────────────┤
# │ 798 rows (20 shown)                                                                          8 columns │
# └────────────────────────────────────────────────────────────────────────────────────────────────────────┘
